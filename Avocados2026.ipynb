# %% [markdown]
# # Avocados2026

# %%
# Import Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Create timestamp and author
from datetime import datetime
time_now = datetime.now().strftime('%m_%d_%Y_%I%M%p')
print('Current Time: {}'.format(time_now))
print('Caitlin Muller')
# Out:
# Current Time: 09_21_2026_0431PM
# Caitlin Muller

# %%
# Read the dataset and store it as data2026
data2026 = pd.read_csv('2026PartYear.csv', encoding = 'utf-8')

# %%
# head shows top 5 rows
data2026.head()
# Out:
#      Report Timeframe  Period          Type                 Geography  \
# 0  Category    Weekly      12  Conventional  5 Boroughs/New York City
# 1  Category    Weekly      11  Conventional  5 Boroughs/New York City
# 2  Category    Weekly      10  Conventional  5 Boroughs/New York City
# 3  Category    Weekly       9  Conventional  5 Boroughs/New York City
# 4  Category    Weekly       8  Conventional  5 Boroughs/New York City
#
#   Current Year Week Ending  ASP Current Year  Total Bulk and Bags  \
# 0               2026/03/22          1.079701          861791.6216
# 1               2026/03/15          1.061474          957397.8336
# 2               2026/03/08          1.046660          919553.7267
# 3               2026/03/01          1.105839          691703.2134
# 4               2026/02/22          1.083417          878922.1500
#
#           4046         4225          4770  TotalBagged   Sml Bagged  \
# 0  141926.1937  325330.2392   3597.595971  390937.5927  339735.8554
# ...

# %%
# show all column names in the data 
data2026.columns
# Out:
# Index(['Report', 'Timeframe', 'Period', 'Type', 'Geography',
#        'Current Year Week Ending', 'ASP Current Year', 'Total Bulk and Bags',
#        '4046', '4225', '4770', 'TotalBagged', 'Sml Bagged', 'Lrg Bagged',
#        'X-Lrg Bagged', 'Unknown Bag Size'],
#       dtype='str')

# %%
# How many rows and columns are in the data
data2026.shape
# Out:
# (4096, 16)

# %%
# show statistic on this file
data2026.describe()
# Out:
#            Period  ASP Current Year  Total Bulk and Bags          4046  \
# count  4096.00000       4096.000000         4.096000e+03  4.096000e+03
# mean     16.50000          1.264223         1.420414e+06  5.835327e+05
# std       9.23422          0.332454         5.849669e+06  2.546395e+06
# min       1.00000          0.680085         3.396173e+03  0.000000e+00
# 25%       8.75000          0.961492         3.688995e+04  9.224932e+02
# 50%      16.50000          1.277168         2.238304e+05  6.174666e+04
# 75%      24.25000          1.497055         7.264622e+05  2.970588e+05
# max      32.00000          2.303274         7.596885e+07  3.250991e+07
#
#                4225          4770   TotalBagged    Sml Bagged    Lrg Bagged  \
# count  4.096000e+03  4.096000e+03  4.096000e+03  4.096000e+03  4.096000e+03
# mean   1.816764e+05  3.391573e+04  6.212895e+05  5.126981e+05  6.436288e+04
# std    7.764623e+05  1.648173e+05  2.427539e+06  1.964420e+06  2.825736e+05
# ...

# %%
# what's in the Type column?
data2026['Type'].unique()
# Out:
# <ArrowStringArray>
# ['Conventional', 'Organic']
# Length: 2, dtype: str

# %%
# what's in Geography
data2026['Geography'].unique()
# Out:
# <ArrowStringArray>
# ['5 Boroughs/New York City',                   'Albany',
#                   'Atlanta',     'Baltimore/Washington',
#     'Birmingham/Montgomery',                    'Boise',
#                    'Boston',        'Buffalo/Rochester',
#                 'Charlotte',                  'Chicago',
#         'Cincinnati/Dayton',                 'Columbus',
#          'Dallas/Ft. Worth',                   'Denver',
#                   'Detroit',             'Grand Rapids',
#       'Harrisburg/Scranton',     'Hartford/Springfield',
#                   'Houston',             'Indianapolis',
#              'Jacksonville',              'Kansas City',
#                 'Knoxville',                'Las Vegas',
#               'Los Angeles',               'Louisville',
#      'Miami/FT. Lauderdale',                'Milwaukee',
#               'Minneapolis',                'Nashville',
#        'New Orleans/Mobile',                 'New York',
# ...

# %% [markdown]
# # Visualization using MatPlotLib and Seaborn

# %%
# Total Units by Type into a Bar Chart
total = data2026.groupby(['Type'])['Total Bulk and Bags'].sum()

# plot bar chart
total.plot(kind = 'bar', figsize=(10,6))

# print values
print(total)
plt.show()
# Out:
# Type
# Conventional    5.528238e+09
# Organic         2.897789e+08
# Name: Total Bulk and Bags, dtype: float64

# %%
# Filter out data
ConventionalOnly = data2026[data2026['Type']!='Organic']

# %%
ConventionalOnly.describe()
# Out:
#             Period  ASP Current Year  Total Bulk and Bags          4046  \
# count  2048.000000       2048.000000         2.048000e+03  2.048000e+03
# mean     16.500000          0.987731         2.699335e+06  1.153555e+06
# std       9.235348          0.155259         8.062509e+06  3.509911e+06
# min       1.000000          0.680085         9.961513e+04  4.288091e+04
# 25%       8.750000          0.873590         3.743296e+05  1.449024e+05
# 50%      16.500000          0.961484         6.997306e+05  2.893811e+05
# 75%      24.250000          1.079544         1.578936e+06  6.454192e+05
# max      32.000000          1.657349         7.596885e+07  3.250991e+07
#
#                4225          4770   TotalBagged    Sml Bagged    Lrg Bagged  \
# count  2.048000e+03  2.048000e+03  2.048000e+03  2.048000e+03  2.048000e+03
# mean   3.503951e+05  6.781053e+04  1.127574e+06  9.140449e+05  1.275591e+05
# std    1.071131e+06  2.281314e+05  3.340447e+06  2.699611e+06  3.894765e+05
# ...

# %%
# Add a revenue column which calculates ASP time Total Bulk and Bags
data2026['Revenue'] = data2026['ASP Current Year'] * data2026['Total Bulk and Bags']

# %%
data2026.head()
# Out:
#      Report Timeframe  Period          Type                 Geography  \
# 0  Category    Weekly      12  Conventional  5 Boroughs/New York City
# 1  Category    Weekly      11  Conventional  5 Boroughs/New York City
# 2  Category    Weekly      10  Conventional  5 Boroughs/New York City
# 3  Category    Weekly       9  Conventional  5 Boroughs/New York City
# 4  Category    Weekly       8  Conventional  5 Boroughs/New York City
#
#   Current Year Week Ending  ASP Current Year  Total Bulk and Bags  \
# 0               2026/03/22          1.079701          861791.6216
# 1               2026/03/15          1.061474          957397.8336
# 2               2026/03/08          1.046660          919553.7267
# 3               2026/03/01          1.105839          691703.2134
# 4               2026/02/22          1.083417          878922.1500
#
#           4046         4225          4770  TotalBagged   Sml Bagged  \
# 0  141926.1937  325330.2392   3597.595971  390937.5927  339735.8554
# ...

# %%
# Bar Chart showing Revenue by Geography

revenue_by_geography = data2026.groupby(['Geography'])['Revenue'].sum()

# Bar Chart
revenue_by_geography.plot(kind = 'bar', figsize = (25,8))
# Out:
# <Axes: xlabel='Geography'>

# %%
# Filter out total date by region
subtotals_to_exclude = ['Total U.S.','West','Southeast','Northeast']
revenue_by_geography = data2026[~data2026['Geography'].isin(subtotals_to_exclude)]

# %%
# Bar Chart showing Revenue by Geography

revenue_by_geography1 = revenue_by_geography.groupby(['Geography'])['Revenue'].sum()

# Bar Chart
revenue_by_geography1.plot(kind = 'bar', figsize = (25,8))
# Out:
# <Axes: xlabel='Geography'>

# %%
# add sort to the chart
revenue_by_geography1_sorted = revenue_by_geography1.sort_values(ascending=False).head(20)

# %%
# bar chart sorted
revenue_by_geography1_sorted.plot(kind = 'bar', figsize = (25,8))
# Out:
# <Axes: xlabel='Geography'>

# %%
# Histogram on Average Selling Price

plt.figure(figsize=(10,10))
numeric_values=['ASP Current Year']
data2026[numeric_values].hist(bins = 20, color = 'red', figsize = (20,10))
plt.show()

# %%
# insert pie chart
labels = '4225','4770','4046'
segments = data2026[['4225','4770','4046']].sum()
explode = (.1,0,0)

fig1,ax1 = plt.subplots()
ax1.pie(segments, explode, labels, shadow=True)
ax1.axis('equal') #equal means a circle

plt.show()
# Out:
# C:\Users\caitl\AppData\Local\Temp\ipykernel_27988\2018197205.py:7: MatplotlibDeprecationWarning: Passing the explode parameter of pie() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   ax1.pie(segments, explode, labels, shadow=True)

# %% [markdown]
# # Add two files together (must be same structure)

# %%
# use concatenate
# Read in the 2025 dataset as data2025

# Read the dataset and store it as data2025
data2025 = pd.read_csv('2025.csv', encoding = 'utf-8')

# %%
new = pd.concat([data2026,data2025])
new.describe()
# Out:
#              Period  ASP Current Year  Total Bulk and Bags          4046  \
# count  10752.000000      10752.000000         1.075200e+04  1.075200e+04
# mean      22.690476          1.347233         1.301195e+06  5.582108e+05
# std       13.982761          0.358597         5.352625e+06  2.434135e+06
# min        1.000000          0.680085         2.917527e+03  0.000000e+00
# 25%       11.000000          1.071707         3.534606e+04  8.407711e+02
# 50%       21.500000          1.341528         2.088700e+05  5.909625e+04
# 75%       32.000000          1.539821         6.727581e+05  2.836431e+05
# max       52.000000          3.117896         7.596885e+07  3.687941e+07
#
#                4225          4770   TotalBagged    Sml Bagged    Lrg Bagged  \
# count  1.075200e+04  1.075200e+04  1.075200e+04  1.075200e+04  1.075200e+04
# mean   1.573253e+05  2.418837e+04  5.614709e+05  4.721105e+05  5.305063e+04
# std    6.740217e+05  1.258893e+05  2.185273e+06  1.802381e+06  2.396413e+05
# ...
